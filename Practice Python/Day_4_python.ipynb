# %% [markdown]
# very important Python conditions: if , else , elif so plz deep thinking your mind

# %%
a = 50 
b = 100 # fast var 

if a > b: #if var operators var : 
    print("a big") 
#tab pess print result show if u pass conditions you not pass so not result show
elif a < b:
    print("b big")
#elif condition mean you not pass if so now elif condition true and show result worked
    if a != b:
        print("a and b not equal")
#again elif to if conditions useable this result not same look operators
else:
    print ( " a = 50 , b = 100")
#else conditions use no var just else: and say result you not pass if elif condition 

###deeply thinking plzzzzz###
# Out:
# b big
# a and b not equal

# %% [markdown]
# example if ,elif ,else ,

# %%
#num=float(input('enter your num: ')) # typeing 20
if num%2==0 and num%5==0:
    print('yes, its divisable by 2 and 5')
elif num%2==0 or num%5==0:
    print('not 1')
else:
    print('not 2')
# Out:
# yes, its divisable by 2 and 5

# %%
#nil = float(input( "Now typeing Number")) 
if nil % 2 == 0:
    print("yes your number divisable by 2") #typeing number 100 result  yes 
    if nil % 5 == 0:
        print("yes your number divisable by 5 ") #typeing 11 result not  
    else:
        print ( "11 is not divisable 5" )
else:
    print ( "13 not divistion" ) #typeing 13 result not
# Out:
# yes your number divisable by 2
# yes your number divisable by 5

# %%
from IPython.display import Image
Image ("use-4-data.png")

# %%
amount = 0
#rs = float(input ("ENTER YOUR UNIT NUMBER"))

if rs <= 100 :
    amount = 0
elif rs > 100 and rs <=200:
    amount = (rs - 100) * 5
elif rs > 200:
    amount = ((rs - 200)* 10) + 500
    
print ( "unit than yor total bill Rs", amount)
